# %% [markdown]
# <a href="https://colab.research.google.com/github/rahafabumelish/Hackation_Mychild_/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='https://raw.githubusercontent.com/abedbanna/AI-Innovators-Hackathon-2025/refs/heads/main/jordan_transactions.csv'
df=pd.read_csv(url)
df.head()
# Out:
#        transaction_id mall_name          branch_name  transaction_date  \
# 0  JO-2504-4466-34760    Z Mall    Z Mall Al Bayader  20/04/2025 20:55
# 1  JO-2504-8444-31356    C Mall         C Mall Amman  20/04/2025 20:37
# 2  JO-2504-3064-71649    Z Mall       Z Mall Gardens  20/04/2025 20:09
# 3  JO-2504-2507-64030    Y Mall  Y Mall Tla'a Al-Ali   17/04/2025 7:03
# 4  JO-2504-1155-35357    C Mall         C Mall Irbid   13/04/2025 6:38
#
#    tax_amount  transaction_amount transaction_type transaction_status
# 0       0.152               2.052             Sale             Failed
# 1       0.152               2.052             Sale             Failed
# 2       0.152               2.052             Sale             Failed
# 3       0.152               2.052             Sale             Failed
# 4       0.070               1.120             Sale             Failed

# %%
# prompt: df.info()
# df.describe()
# df['transaction_status'].value_counts()
# df['transaction_type'].value_counts()
# df['branch_name'].unique()

df.info()
df.describe()
df['transaction_status'].value_counts()
df['transaction_type'].value_counts()
print(df['branch_name'].unique())
df['transaction_date'] = pd.to_datetime(df['transaction_date'], format='%d/%m/%Y %H:%M')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transaction_id      1752 non-null   object
#  1   mall_name           1752 non-null   object
#  2   branch_name         1752 non-null   object
#  3   transaction_date    1752 non-null   object
#  4   tax_amount          1752 non-null   float64
#  5   transaction_amount  1752 non-null   float64
#  6   transaction_type    1752 non-null   object
#  7   transaction_status  1752 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 109.6+ KB
# ['Z Mall Al Bayader' 'C Mall Amman' 'Z Mall Gardens' "Y Mall Tla'a Al-Ali"
#  'C Mall Irbid' 'Z Mall Al Jubeiha' 'Y Mall Shmeisani' 'Y Mall Dabouq'
#  'C Mall Aqaba']

# %%
# !pip install langchain openai faiss-cpu tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.6 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# ...

# %%
texts = []

for idx, row in df.iterrows():
    text = f"""
    Transaction ID: {row['transaction_id']}
    Mall Name: {row['mall_name']}
    Branch Name: {row['branch_name']}
    Transaction Date: {row['transaction_date']}
    Tax Amount: {row['tax_amount']}
    Transaction Amount: {row['transaction_amount']}
    Transaaction Type: {row['transaction_type']}
    Transaction Status: {row['transaction_status']}
    """
    texts.append(text.strip())

# %%
# !pip install -U langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.7/437.7 kB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.56
#     Uninstalling langchain-core-0.3.56:
#       Successfully uninstalled langchain-core-0.3.56
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings, HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.schema import Document
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
import os
from tqdm import tqdm

# %%
url = "https://raw.githubusercontent.com/abedbanna/AI-Innovators-Hackathon-2025/main/jordan_transactions.csv"
df = pd.read_csv(url)

# تصحيح البيانات
df['transaction_date'] = df['transaction_date'].str.replace('2004/2025', '25/04/2025')
df['transaction_date'] = pd.to_datetime(df['transaction_date'], format='%d/%m/%Y %H:%M', errors='coerce')

# عرض البيانات
print("البيانات بعد التنظيف:")
display(df.head())
# Out:
# البيانات بعد التنظيف:
#        transaction_id mall_name          branch_name    transaction_date  \
# 0  JO-2504-4466-34760    Z Mall    Z Mall Al Bayader 2025-04-20 20:55:00
# 1  JO-2504-8444-31356    C Mall         C Mall Amman 2025-04-20 20:37:00
# 2  JO-2504-3064-71649    Z Mall       Z Mall Gardens 2025-04-20 20:09:00
# 3  JO-2504-2507-64030    Y Mall  Y Mall Tla'a Al-Ali 2025-04-17 07:03:00
# 4  JO-2504-1155-35357    C Mall         C Mall Irbid 2025-04-13 06:38:00
#
#    tax_amount  transaction_amount transaction_type transaction_status
# 0       0.152               2.052             Sale             Failed
# 1       0.152               2.052             Sale             Failed
# 2       0.152               2.052             Sale             Failed
# 3       0.152               2.052             Sale             Failed
# 4       0.070               1.120             Sale             Failed

# %%
print(f"عدد الصفوف: {len(df)}")
print("\nإحصائيات المبالغ:")
print(df['transaction_amount'].describe())

# رسم بياني
plt.figure(figsize=(10, 5))
sns.histplot(df['transaction_amount'], bins=30)
plt.title('توزيع قيم المعاملات')
plt.show()
# Out:
# عدد الصفوف: 1752
#
# إحصائيات المبالغ:
# count    1752.000000
# mean        8.362489
# std         6.745610
# min         0.053500
# 25%         3.270000
# 50%         6.550000
# 75%         9.930000
# max        85.520000
# Name: transaction_amount, dtype: float64
